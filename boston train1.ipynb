# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("train1.csv")
a
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
a.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
a.columns .value_counts()
# Out:
# PavedDrive       1
# 2ndFlrSF         1
# HeatingQC        1
# OverallCond      1
# RoofMatl         1
#                 ..
# SaleCondition    1
# Id               1
# ExterQual        1
# LandSlope        1
# MoSold           1
# Length: 81, dtype: int64

# %%
a.loc[:,:]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
a.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
a.fillna(1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave     1      Reg
# 1        2          20       RL         80.0     9600   Pave     1      Reg
# 2        3          60       RL         68.0    11250   Pave     1      IR1
# 3        4          70       RL         60.0     9550   Pave     1      IR1
# 4        5          60       RL         84.0    14260   Pave     1      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave     1      Reg
# 1456  1457          20       RL         85.0    13175   Pave     1      Reg
# 1457  1458          70       RL         66.0     9042   Pave     1      Reg
# 1458  1459          20       RL         68.0     9717   Pave     1      Reg
# 1459  1460          20       RL         75.0     9937   Pave     1      Reg
#
# ...

# %% [markdown]
# ### Train a univarint linear regression

# %% [markdown]
# a=(a.corr()>0.3).sum()
# a

# %%
(a.corr()>0.3).sum() 
a
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
x=a[["GrLivArea"]]
x
# Out:
#       GrLivArea
# 0          1710
# 1          1262
# 2          1786
# 3          1717
# 4          2198
# ...         ...
# 1455       1647
# 1456       2073
# 1457       2340
# 1458       1078
# 1459       1256
#
# [1460 rows x 1 columns]

# %%
x.ndim
# Out:
# 2

# %%
y=a[["SalePrice"]]
y
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %%
x.shape
# Out:
# (1460, 1)

# %%
y.shape
# Out:
# (1460, 1)

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest =train_test_split(x, y, random_state =2,test_size=0.2, shuffle = True)

# %%
 from sklearn import linear_model

# %%
model=linear_model.LinearRegression()

# %%
testing=a[["GrLivArea"]]
testing
# Out:
#       GrLivArea
# 0          1710
# 1          1262
# 2          1786
# 3          1717
# 4          2198
# ...         ...
# 1455       1647
# 1456       2073
# 1457       2340
# 1458       1078
# 1459       1256
#
# [1460 rows x 1 columns]

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.predict(xtest)
# Out:
# array([[209951.56029094],
#        [202805.55845676],
#        [354217.94514631],
#        [152576.41512951],
#        [164072.15721059],
#        [213887.03956194],
#        [186338.68466494],
#        [201666.34077304],
#        [141494.93402432],
#        [213783.47431797],
#        [189342.07674017],
#        [164072.15721059],
#        [125649.45169635],
#        [139630.7596328 ],
#        [149158.76207838],
#        [260284.26886216],
#        [257798.70300679],
#        [192138.33832746],
#        [267637.40118429],
#        [320869.93658677],
#        [231286.00054952],
#        [175775.02977962],
#        [182610.33588188],
#        [255002.4414195 ],
#        [328430.19939685],
#        [201562.77552907],
#        [167593.3755057 ],
#        [264634.00910905],
#        [178881.98709883],
#        [305956.54145456],
#        [191206.2511317 ],
#        [170078.94136107],
#        [284414.97070803],
#        [131138.40962695],
#        [192449.03405939],
# ...

# %%
model.score(xtrain,ytrain)
# Out:
# 0.47117932290992637

# %%
plt.scatter(xtrain,ytrain)

# %%
a.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
plt.scatter(xtrain,ytrain,)
plt.plot(testing,model.predict(testing),color="red")

# %%
x1=a[["OverallQual","1stFlrSF","GrLivArea","FullBath","GarageCars","GarageArea"]]
x1
# Out:
#       OverallQual  1stFlrSF  GrLivArea  FullBath  GarageCars  GarageArea
# 0               7       856       1710         2           2         548
# 1               6      1262       1262         2           2         460
# 2               7       920       1786         2           2         608
# 3               7       961       1717         1           3         642
# 4               8      1145       2198         2           3         836
# ...           ...       ...        ...       ...         ...         ...
# 1455            6       953       1647         2           2         460
# 1456            6      2073       2073         2           2         500
# 1457            7      1188       2340         2           1         252
# 1458            5      1078       1078         1           1         240
# 1459            5      1256       1256         1           1         276
#
# [1460 rows x 6 columns]

# %%
y1=a[["SalePrice"]]
y1
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

x1train, x1test, y1train, y1test =train_test_split(x1, y1, random_state =2,test_size=0.2, shuffle = True)

# %%
model.fit(x1train,y1train)
# Out:
# LinearRegression()

# %%
model.score(x1train,y1train)
# Out:
# 0.7376402557890067

# %%
x1train.shape
# Out:
# (1168, 6)

# %%
(x1train)
# Out:
#       OverallQual  1stFlrSF  GrLivArea  FullBath  GarageCars  GarageArea
# 455             7      1242       1242         1           2         528
# 863             5      1148       1148         1           1         672
# 504             6       855       1322         2           2         440
# 1413            8      1844       1844         2           2         620
# 1389            6       869       1218         1           2         440
# ...           ...       ...        ...       ...         ...         ...
# 466             7      1277       1277         1           2         526
# 299             6      1152       1152         1           1         300
# 493             5      1269       1269         1           1         308
# 527             9      1476       2713         2           3         858
# 1192            5       842       1472         1           1         250
#
# [1168 rows x 6 columns]

# %%
y1train.shape
# Out:
# (1168, 1)

# %%
plt.scatter(x1train,y1train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-87fb500d1192> in <module>
# ----> 1 plt.scatter(x1train,y1train)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...

# %%
model.score(xtest,ytest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-c1034acc2ae8> in <module>
# ----> 1 model.score(xtest,ytest)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# ...

# %%
plt.scatter(x1train[["OverallQual"]],y1train,color="blue")
plt.scatter(x1train["1stFlrSF"],y1train,color="green")
plt.scatter(x1train["GrLivArea"],y1train,color="red")
plt.scatter(x1train["FullBath"],y1train,color="pink")
plt.scatter(x1train["GarageCars"],y1train,color="yellow")
plt.scatter(x1train["GarageArea"],y1train,color="black")
plt.plot(testing1,model.predict(testing1))

# %%
plt.(x1train[["OverallQual"]],y1train,color="blue")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-222dfb6183e8> in <module>
# ----> 1 plt.vbar(x1train[["OverallQual"]],y1train,color="blue")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'vbar'

# %%
q=["Multiverient_Score"]=[model.score(x1test,y1test)]
q
# Out:
#   File "<ipython-input-52-29225361f34b>", line 1
#     q=["Multiverient_Score"]=[model.score(x1test,y1test)]
#       ^
# SyntaxError: cannot assign to literal
